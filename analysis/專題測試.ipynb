# %%
f = open('place.txt','w')
for line in open('apple.txt'):
    k = line.strip().split(',')
    for i in k:
        if i !="":
            if i!=k[0]:
                f.write(k[0]+','+i)
                f.write('\n')
f.close()

# %%
for line in open('place.txt'):
    print line.strip().split(',')[1]
# Out:
# 誠品書店
# 女書店
# 中山創意基地URS 21
# 臺北中山堂
# 中山堂
# 中山樓
# VVG好樣
# 學學文創
# 臺北藝術大學
# 國立臺北大學
# 實踐大學
# 國立臺北大學
# 華山1914文化創意產業園區
# 文化部
# 台北之家(光點台北)
# 光點台北
# 台北之家
# 松山文化創意園區
# 文化部
# 寶藏巖
# 寶藏岩國際藝術村
# 寶藏岩
# 寶藏巖國際藝術村
# 信義公民會館(四四南村)
# 四四南村 (信義公民會館)
# 四四南村眷村文物館
# 南村落
# 四四南村
# 臺北市立圖書館北投分館
# 北投
# 台北市立圖書館北投分館
# 台北101
# 台北101觀景台
# 台北101景觀台
# 台北101(Taipei 101)
# 市政府站台北101周邊
# 台北101大樓
# 艋舺龍山寺
# 龍山寺
# 臺北龍山寺
# 樟山寺
# 北投溫泉博物館
# 北投溫泉親水區
# 北投溫泉自行車道
# 北投溫泉
# 北投溫泉步道
# 新北投溫泉區
# 北投溫泉泡腳池
# 北投溫泉公共浴室
# 北投溫泉圖書館
# 新北投溫泉
# 北投
# 北投溫泉路
# 北投溫泉親水公園
# 溫泉街
# 中山堂
# 臺北市公有中山市場
# 台北捷運中山站線型公園
# 台北中山堂
# 中山康樂公園
# 中山公民會館
# 中山教會
# 中山堂(Taipei Zhongshan Hall)
# 圓山花博公園-中山親子館
# 陽明山中山樓
# 中山八德環保教育站
# 中山樓
# 中山大樓
# 中山創意區
# 中山基督長老教會
# 中山美術公園
# 台北中山地下街
# 中山市場
# 中山足球場
# 中山精品圈
# 中山北路商圈
# 林語堂故居
# 林語堂故居(原林語堂先生紀念館)
# 國立臺灣博物館 (土銀展示館)
# 國立台灣博物館土銀展示館
# 國立臺灣博物館(土銀展示館)
# 國立臺灣博物館
# 國立台灣博物館
# 中正紀念堂(自由廣場)
# 中正紀念堂 (自由廣場)
# 自由廣場
# 國父紀念館
# 國立國父紀念館
# 剝皮寮
# 剝皮?
# 剝皮寮老街
# 剝皮寮歷史街區。剝皮寮老街
# 台北市鄉土教育中心(剝皮寮歷史街區)
# 臺北市鄉土教育中心(剝皮寮歷史街區)
# 總統府
# 總統副總統文物館
# 台北總統府
# 士林官邸
# 忠烈祠
# ...

# %%
import os
import re
file_array = os.listdir('ptt1')  
list1 = []

for line in open('place.txt'):
    q = line.strip().decode('utf-8')
    if q.split(',')[1] !='':
        list1.append(q)

for j in range(1,len(file_array)):
    filename = file_array[j]
    path = 'ptt1/'+file_array[j]
    a = open(path,'r').read().decode('utf-8')
    k = re.sub(u'<br />|；|，|！|[A-Za-z]|,|=|[〕]|\+|[▲]|[＞]|[￣]|[＜]|[☑]|[〔]|[█]|[▓]|$|\{|\}|<|>|「|」|[〃]|[§]|\'|[／]|[↓]|[→]|^|_|@|[＃]|[？]|&|[●]|[～]|3|4|5|6|7|9|。|[.]| |[\n]|、|發信站: 批踢踢實業坊\(ptt.cc\)|（|）|[▼]|[【]|[】]|"|[◆]|※|[[]|[]]|~|/|“|”|[*]|：|%|[?]|-|:|!|…|[★]|·|;|》|[)]|[(]|《|　|','',a)
    b = filename.split('.txt')[0] + "," +k
    #print b
    count = 0
    for i in list1:
        if i.split(',')[1] in b:
            print b.split(',')[0] + "," + i
            count+=1
    if count ==0:
        print filename + "XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX"
    else:
        print count
# Out:
# 10.txtXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# 100,43,陽明山
# 100,55,陽明山
# 100,117,陽明山
# 100,142,陽明山
# 100,176,大屯山
# 100,177,大屯山
# 100,189,大屯山
# 100,191,陽明山
# 100,197,大屯山
# 100,230,大屯山
# 100,335,公園
# 100,349,陽明山
# 100,354,陽明山
# 100,767,陽明山
# 100,777,陽明山
# 100,786,公園
# 100,791,陽明山
# 100,869,陽明山
# 100,1223,陽明山
# 100,1225,陽明山
# 100,1245,陽明山
# 100,1265,陽明山
# 100,1266,大屯山
# 100,1270,陽明山
# 100,1278,大屯山
# 100,1279,陽明山
# 100,1285,大屯山
# 100,1292,大屯山
# 100,1353,陽明山
# 100,1506,公園
# 100,1541,陽明山
# 31
# 1000.txtXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# 101,15,溫泉博物館
# 101,15,溫泉
# 101,15,溫泉泡腳池
# 101,36,梅庭
# 101,36,梅庭
# 101,43,陽明山
# 101,44,溫泉區
# 101,44,溫泉博物館
# 101,44,溫泉泡腳池
# 101,55,陽明山
# 101,117,陽明山
# 101,141,圖書館
# 101,142,陽明山
# 101,144,地熱谷
# 101,144,地熱谷
# 101,176,大屯山
# 101,177,大屯山
# 101,189,大屯山
# 101,191,陽明山
# 101,197,大屯山
# 101,230,大屯山
# 101,335,公園
# 101,349,陽明山
# 101,354,陽明山
# 101,513,復興公園
# 101,523,泉源公園
# 101,527,七星公園
# 101,566,地熱谷
# 101,767,陽明山
# 101,777,陽明山
# 101,786,公園
# ...

# %%
import os
import re
file_array = os.listdir('ptt1')  
list1 = []

for line in open('place.txt'):
    q = line.strip().decode('utf-8')
    if q.split(',')[1] !='':
        list1.append(q)

for j in range(1,len(file_array)):
    filename = file_array[j]
    path = 'ptt1/'+file_array[j]
    a = open(path,'r').read().decode('utf-8')
    k = re.sub(u'<br />|；|，|！|[A-Za-z]|,|=|[〕]|\+|[▲]|[＞]|[￣]|[＜]|[☑]|[〔]|[█]|[▓]|$|\{|\}|<|>|「|」|[〃]|[§]|\'|[／]|[↓]|[→]|^|_|@|[＃]|[？]|&|[●]|[～]|3|4|5|6|7|9|。|[.]| |[\n]|、|發信站: 批踢踢實業坊\(ptt.cc\)|（|）|[▼]|[【]|[】]|"|[◆]|※|[[]|[]]|~|/|“|”|[*]|：|%|[?]|-|:|!|…|[★]|·|;|》|[)]|[(]|《|　|','',a)
    b = filename.split('.txt')[0] + "," +k
    #print b
    count = 0
    for i in list1:
        if i.split(',')[1] in b:
            print b.split(',')[0] + "," + i.split(',')[0]
