# %%
import jieba
import pandas as pd 
import simplejson as json
from six import iteritems, itervalues, string_types

# %%
with open('dump.out') as f:
    docs = f.readlines()

# %%
docs = [json.loads(d) for d in docs]

# %%
doc_df = pd.DataFrame(docs)

# %%
doc_df.shape
# Out:
# (5835, 6)

# %%
doc_df[:3]
# Out:
#                                              content            created_at  \
# 0  永豐金(2890)晉升百億俱樂部，去年(2013)稅後淨利來到103億元，年增率超過1成，董...  2014-02-13 10:57:33
# 1  永豐金控（2890）子公司永豐銀行2013年4月引資大陸中國工商銀行參股20%，雙方簽訂備忘...  2014-02-13 11:00:18
# 2  經部昨天提出服貿協議本會期過關的因應策略向江揆報告，同時針對服貿協議開放市場的敏感性議題，向...  2014-02-13 13:06:32
#
#                                                 link  score     source  \
# 0    http://www.ettoday.net/news/20140212/324561.htm      1  東森EtToday
# 1  http://udn.com/NEWS/BREAKINGNEWS/BREAKINGNEWS6...      2      聯合新聞網
# 2  http://www.chinatimes.com/newspapers/201402130...      1       工商時報
#
#             title
# 0    何壽川：永豐金不排斥併購
# 1  永豐銀引資大陸工行 可望續約
# 2        江揆下部會動員令

# %%
with open("cut_content.txt", "w") as f:
    contents_cut = [jieba.cut(content) for content in doc_df['content']]
    for content in contents_cut:
        doc = ' '.join(content)
        f.writelines(doc.encode('utf-8'))
# Out:
# Building prefix dict from C:\Users\BigData\Anaconda2\lib\site-packages\jieba\dict.txt ...
# DEBUG:jieba:Building prefix dict from C:\Users\BigData\Anaconda2\lib\site-packages\jieba\dict.txt ...
# Loading model from cache c:\users\bigdata\appdata\local\temp\jieba.cache
# DEBUG:jieba:Loading model from cache c:\users\bigdata\appdata\local\temp\jieba.cache
# Loading model cost 0.270 seconds.
# DEBUG:jieba:Loading model cost 0.270 seconds.
# Prefix dict has been built succesfully.
# DEBUG:jieba:Prefix dict has been built succesfully.

# %%
from gensim import models

# %%
sentences = models.word2vec.LineSentence("cut_content.txt")

# %%
model = models.word2vec.Word2Vec(sentences, size=50, window=5, min_count=5, workers=1)
# Out:
# WARNING:gensim.models.word2vec:consider setting layer size to a multiple of 4 for greater performance
# C:\Users\BigData\Anaconda2\lib\site-packages\gensim\models\word2vec.py:675: UserWarning: C extension not loaded for Word2Vec, training will be slow. Install a C compiler and reinstall gensim for fast training.
#   warnings.warn("C extension not loaded for Word2Vec, training will be slow. "

# %%
print ' '.join(model.vocab.viewkeys())
# Out:
# 微型 遠大 意表 硬拗 第二 台灣金 極少 雙手 位階高 國際誠信 預 明確 只用 過許 聯準 開協商 作弊 占會議 。總統府 星期一 一樣 將到 轉貼 礦 沿著 手續 有史 活機會 期抗 河 憲 別無選擇 偷偷 打天下 吸 實上 傳到 看作 陸用 分開始 談 洶湧 台灣醒 開放導致 反 牌 調高至 防衛 困境 持穩 增 行動來 年後大陸 自全國 監 有取 藥產學 質詢 看似 升起 遠 之爭 綺 知 除 一樓 緩 余美慧 第五 西藏 頭破 歲 台辦 群眾手 甚為 48 二十五 智庫 串聯 至此 把關 高興 高舉 第七 第一 居上 晚清 經揚言 mail 急動員令 綠委們 第三 星期五 漸漸 275 
將難 勞動力 唐湘龍 無視 最為 顯示 千箱 公約數 總 室主任 阿扁 天來 權凌駕 無解 頻頻 歷史會 實話 前面 藍 降 剎車 業及 新頭 展台 應占領 維修業 空缺 保證會 適逢 省思 週續 哪個 廣場 云云 搶回 美竊 離 古 一道 運今 早點 獲利竅門 還沒開 華信 獵刀 接機 洞開 區內 女朋友 振強 管理法 促統 機會給 古坑 學生並 戰鬥機 僅有 光產業 三項 主任 計 輛遊覽車 開竅 作多 夾帶 傾銷 相關業者 潛艇 學生靜 大經濟體 中衝 麻煩 因服 勝等 反核 窠臼 將長 結打開 值班 罪人 Ｆ 暫 外快 遇阻 既有 經比 。立法院 愉快 料及 文章 瘦 挺外 或系 這張 遭霸 嶽 結聯盟 同步 白發 免 何韻 加緊 進會場 主人 雨 監控 過大 日開 官署 煞車 藍委搶 起跳 呼籲應 為念 護盤 拿到 打內 打入 深深 六輕 霸凌 餐 王廣樹 睡袋 奪 張善政 總指揮 免受 過夜 其內容 動態 機制 攻大陸 其士氣 要簽 言表 監督條 淘寶變法 異動 值得注意 競選廣告 瘋 管中 北上 一次 施旖婕 敵人 犧牲者 銷 陸方並 當選 折 代議 答詢 無調 遊覽車 追逐 for 而當 痛批 上修 當過 大任務 脫下 放手 Facebook cnYES 法律 台灣面 手腕 均須 楊翠 何需 不影響 打出 勝算 是贊 證 家事 施政 施放 閣 偏 最珍 星星 緒 談時 壁壘 盤整 號的 將開 施振榮 一波 因 以外 及靜 概括 聚 厲害 ASEAN 擬 聯 否認 台新金 不帶 榮譽 成員 無論 占據 誓言 駐美 技術資 東部 懲處 Fed 助人 同樣 邁則 由國會 金銀三會 囿 行黨 今年年底 轉變 家台灣 紅線 殯儀館 ！新頭 供 週委員會 貝 諷刺 大紀元 解釋 以行 僅是 無謂 務業 要給 警官 ] 簡直 前開 仍舊 打個 估 我心 烽火 民選 去除 週五是 一派 宣傳服 大戰本 萬華區 一流 邀集 收入 電視台 受邀 開放外 將簽署 失望 將很難 界 量 強推 寄生 1846 悲哀 地被 名璽 燃燒 睡覺 不眠不休 盡 靠 業內 呢 給年 內 點不遠 案審查 轟炸 可不可以 警察 命除 晴天 Tony 海島型 前民進 零星 門會 對象 154 自治 召委為 看 打傷 有力 而立 法庭 校院 談會 行使 收視率 輛 已經成 醜陋 上市 對言論 我們還 外幣 深水 會振興 涉台 林鴻池並 門議 金馬 內資 卓越 以維護 資產 美經濟 有心人士 簽 假 ...

# %% [raw]
# for w in itervalues(model.vocab):
#     print w

# %% [raw]
# for no, word in enumerate(model.vocab):
#     print no, word

# %%
model.syn0
# Out:
# array([[ 0.08039947,  0.0060935 ,  0.34810349, ...,  0.2644282 ,
#          0.05441136, -0.0804491 ],
#        [ 0.02450238,  0.33259881,  0.07490119, ..., -0.0602354 ,
#         -0.08602461, -0.16612747],
#        [ 0.136132  ,  0.18472435,  0.20602544, ...,  0.11139681,
#          0.01964634, -0.03783556],
#        ...,
#        [ 0.04733779, -0.13666631,  0.00811207, ..., -0.03568356,
#         -0.03795432,  0.00887684],
#        [-0.00511242, -0.10577464, -0.04439528, ..., -0.13135836,
#          0.06324963,  0.20084335],
#        [ 0.01263688, -0.02356312,  0.00945647, ..., -0.00687645,
#         -0.03245846,  0.00802881]], dtype=float32)

# %%
model.syn0.shape
# Out:
# (20059L, 50L)

# %%
len(model.vocab)
# Out:
# 20059

# %%
model.syn1.shape
# Out:
# (20059L, 50L)

# %%
from collections import Counter
from sklearn import  cluster
import numpy as np
from scipy.spatial.distance import pdist
from scipy.cluster.hierarchy import linkage
from sklearn.cluster import hierarchical

# %%
model.init_sims()

# %%
model.syn0norm
# Out:
# array([[ 0.07182184,  0.0054434 ,  0.31096515, ...,  0.23621699,
#          0.04860634, -0.07186618],
#        [ 0.0209897 ,  0.28491709,  0.06416328, ..., -0.05159999,
#         -0.07369204, -0.14231128],
#        [ 0.12365757,  0.16779716,  0.18714634, ...,  0.10118899,
#          0.01784605, -0.03436851],
#        ...,
#        [ 0.06664105, -0.19239569,  0.01141999, ..., -0.05023449,
#         -0.05343122,  0.01249662],
#        [-0.00727993, -0.15061991, -0.06321754, ..., -0.18705034,
#          0.09006556,  0.28599489],
#        [ 0.05965452, -0.11123368,  0.04464087, ..., -0.03246145,
#         -0.15322563,  0.03790134]], dtype=float32)

# %%
kmean = cluster.KMeans(n_clusters=10)
result = kmean.fit(model.syn0norm)

# %%
Counter(result.labels_)
# Out:
# Counter({0: 3340,
#          1: 1359,
#          2: 1668,
#          3: 1862,
#          4: 2197,
#          5: 1563,
#          6: 1804,
#          7: 1249,
#          8: 2842,
#          9: 2175})

# %%
label = 4
print " ".join(np.array(model.index2word)[result.labels_ == label])
# Out:
# 黨 民進 立委 張慶忠 會議 政委 員會 其邁 開會 杯葛 主席台 委員 召委 進黨 黨籍 排案 聯席 國民黨籍 宣告 場公聽會 藍綠 審服貿 散會 綠營 多次 逕 議程 各委員會 排定 慣例 提案 阻擋 陷入 召委陳 藍營 個常 空轉 安排 登記 自行 議事錄 團大會 刻意 審服 兩黨 攻防 秒 宣讀 有效 週 議室 便 一開始 高志 宣 肢體 認定 事錄 上演 小組 籤 順序 臨時 取消 指控 突襲 優先 上周 聯席會 強力 對策 各自 硬 背 互相 昇 本周 藍委 幹事長 藍 阻止 下周 案 但民進 吵 承認 零 同一 大戰 依舊 確認 任務 因服 全體 團則 排入 一路 攻擊 排審 隨後 揚言 主導權 綠 可見 查案 全數 女 七 只好 躲 竟 法定 邱議瑩 法規定 下週 此時 初審 僵持 否認 吳育 果 戰 異議 趁亂 瑕疵 還沒 拉扯 若有 公報 備戰 幾 違憲 系統 不理 個委員會 開議 吳秉叡 中立 鞭 手法 核四 葆 61 手上 輪值 管碧玲 口角 主審 惡意 召委張 不願意 王育敏 不正 聯席會議 修法 議事處 李俊 但國民黨 排 大禮堂 緊 推倒 不成 林鴻池則 周 江惠貞 惡鬥 抽 新會期 禮拜 否決 一邊 大法官 砲 派出 即可 不肯 何時 林淑芬 賴士 混戰 會議室 不承認 釋出 搶攻 公職 多場 動員令 原 戰場 反制 
入 總務處 幾點 買單 下個 第一位 持久 暗諷 清泉 擔心民 動手 內閣制 全黨 地面 寄給 見招 中國國 週四 成會 憲政規定 矚目 醫務室 人手 引發民 不承 又將 並展 組團 餐敘 音響 批國民黨 沒法 緩辦 回擊 軍令狀 蔡錦隆 一審 清一色 占先 還宣稱 過服 剛才 有民進 一召委 急動員 依慣例 四成 還對 的則 洪水 姚文智 台聯將 王郁琦會 沒意 譴責國民黨 妄想 案審查 黨應 借用 剛 前夕 尹啟 抵 召委輪流 有效性 但會議 認會議 攻守 改由 防委員會 例應 餵 無賴 第九 無解 設下 唸完 該表決 院中 力阻 許國民黨 歧視 先將 互不 再行 聽聞 參事 談判桌 地將 節如 旋即 陳淑惠 所為 以黨 轉戰 達動員令 發說 團來 發言權 力保 管理法 貸 再排 避開 依國安 追加 請民進 劉建國 排在後面 免不了 好意 不太 團質疑 並爆發 三名 數及 一級 關門 鵬則 排開 顧好 一席 區內 偷跑 壓著 責無旁 錯愕 還把 服貿本 張慶忠將 領到 發言時 還以 還來 分組 也絕 以閃電 隨之 中民進 員會將 第六十一 音量 仍無法 茲 名冊 武器 亂成 並輪番 生民 肉搏 此協議 司馬昭之心 成一團 開打 延到 儀式 預先 林滄敏 夾帶 召委時 差點 拿起 召委則 確 遂 召委人選 與民進 大罵 猛烈 提散 團要 登載 唱名 ！立法院 認為現 倪安 開會時 一邊念 徐少萍 力主 若下 支隱 交通委 商議 。蘇貞昌 將發動 團持 倒地 原在 不懷 重排 真要 八壯丁 六個 福利部 將由 另行 無線 竟是 以爭 有別 三場 一整 無異議 恰當 綠營則 合情合理 有略 滿場 表情 投下 問民進 字幕 單方 譴責民 送出去 今起 娘子 台賓館 武行 前次 郝 字樣 委員將 覆 搬出 不會用 此話 桌 邁並 自省 手臂 則有 多處 成員士氣 堇 黨意 據悉 蘇貞昌還 開到 認帳 奉陪到底 隨後將 顯示民 硬碰硬 改採 推派 虛耗 壯漢 堅 林岱 空缺 口頭 召委排 新一 ...

# %%
index = result.labels_ == label
dist = pdist(np.array(model.syn0norm)[index])
m = linkage(dist, method='average')
h = hierarchical.hierarchy.fcluster(m, 0.5*dist.max(), 'distance')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-40-4ac4383fcb92> in <module>()
#       2 dist = pdist(np.array(model.syn0norm)[index])
#       3 m = linkage(dist, method='average')
# ----> 4 h = hierarchical.hierarchy.fcluster(m, 0.5*dist.max(), 'distance')
#
# AttributeError: 'module' object has no attribute 'hierarchy'

# %%
Counter(h)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-d1c305b8c4c1> in <module>()
# ----> 1 Counter(h)
#
# NameError: name 'h' is not defined

# %%
print ' '.join(np.array(model.index2word)[index][h == 503])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-a2215ea3c78d> in <module>()
# ----> 1 print ' '.join(np.array(model.index2word)[index][h == 503])
#
# NameError: name 'h' is not defined

# %%
print ' '.join(np.array(model.index2word)[index][h == 508])
# Out:
# 搜索 記錄 31.84

# %%
label = 7
print " ".join(np.array(model.index2word)[result.labels_ == label])
# Out:
, 364: 1, 365: 1, 367: 1, 370: 1, 371: 1, 372: 1, 376: 1, 380: 1, 383: 1, 384: 1, 385: 1, 389: 1, 391: 1, 392: 1, 393: 1, 394: 1, 395: 1, 396: 1, 397: 1, 401: 1, 404: 1, 405: 1, 406: 1, 408: 1, 410: 1, 411: 1, 413: 1, 414: 1, 415: 1, 418: 1, 420: 1, 421: 1, 423: 1, 430: 1, 431: 1, 433: 1, 434: 1, 435: 1, 437: 1, 440: 1, 441: 1, 444: ...

# %%
print ' '.join(np.array(model.index2word)[index][h == 523])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-a8d3f0104a11> in <module>()
# ----> 1 print ' '.join(np.array(model.index2word)[index][h == 523])
#
# NameError: name 'h' is not defined

# %%
print ' '.join(np.array(model.index2word)[index][h == 527])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-fb71cca324e1> in <module>()
# ----> 1 print ' '.join(np.array(model.index2word)[index][h == 527])
#
# NameError: name 'h' is not defined

# %%
label = 4
print " ".join(np.array(model.index2word)[result.labels_ == label])
# Out:
# 黨 民進 立委 張慶忠 會議 政委 員會 其邁 開會 杯葛 主席台 委員 召委 進黨 黨籍 排案 聯席 國民黨籍 宣告 場公聽會 藍綠 審服貿 散會 綠營 多次 逕 議程 各委員會 排定 慣例 提案 阻擋 陷入 召委陳 藍營 個常 空轉 安排 登記 自行 議事錄 團大會 刻意 審服 兩黨 攻防 秒 宣讀 有效 週 議室 便 一開始 高志 宣 肢體 認定 事錄 上演 小組 籤 順序 臨時 取消 指控 突襲 優先 上周 聯席會 強力 對策 各自 硬 背 互相 昇 本周 藍委 幹事長 藍 阻止 下周 案 但民進 吵 承認 零 同一 大戰 依舊 確認 任務 因服 全體 團則 排入 一路 攻擊 排審 隨後 揚言 主導權 綠 可見 查案 全數 女 七 只好 躲 竟 法定 邱議瑩 法規定 下週 此時 初審 僵持 否認 吳育 果 戰 異議 趁亂 瑕疵 還沒 拉扯 若有 公報 備戰 幾 違憲 系統 不理 個委員會 開議 吳秉叡 中立 鞭 手法 核四 葆 61 手上 輪值 管碧玲 口角 主審 惡意 召委張 不願意 王育敏 不正 聯席會議 修法 議事處 李俊 但國民黨 排 大禮堂 緊 推倒 不成 林鴻池則 周 江惠貞 惡鬥 抽 新會期 禮拜 否決 一邊 大法官 砲 派出 即可 不肯 何時 林淑芬 賴士 混戰 會議室 不承認 釋出 搶攻 公職 多場 動員令 原 戰場 反制 組織法 團會議 打人 各有 一整天 就此 角落 不休 一團 段 僵持不下 周一 阻撓 翻 質詢 一戰 錄音 席 終結 總質詢 正當性 星期 行程 一日 黨將 拜 黨會 出席人 力推 爭執 內政 兩人 直指 發言登 戰術 張慶忠以 四大 前例 蕭美琴 九月 移送 開完 備 亂紀 點半 人事 搶排 周三 種種 理 反擊 很難 台聯黨 接近 爭論 俋 扭打 抨擊 拿到 追問 立 召委陳其 遭民進 黨則 辛勞 絕不會 意圖 先排 無意 不予 抵制 延長 台下 自始 喇叭 對抗 貿送 違反議 拿下 一人 旁邊 即發 成服 黨員 此舉 一觸 妨礙 仍將 。國民黨 提議 承 簽到 勸 宣判 預定 賴振
 李秋美 依規定 出示 及國 朝 三思 服貿時 堅稱 敬告 紀律 高潮 黑白 放話 沙盤 倒果 喊冤 服貿視 吵成 服貿送 咖 王張會 觀感 無限 藍綠大戰 天才 刪 火爆 攤 奉 台前 互控 對會 拿著 善 會開 走著 海協會 由民 瞬間 上次 繃 除此之外 蕭萬長 固定 戒嚴 這週 已將 五點 六年 星期三 聲請 百 然無存 排隊 主戰場 同黨 超級 官司 派員 點時 交院 前要 眼見 預算案 1030317 戰火 並進行 商定 換成 中將 慶忠 照常 許信良 鷹派 發酵 李應元 商討 桌子 週將 會見 祭 如有 圍繞 無天 釋字 將他 由國民黨 有備 這番 因國民黨 一架 涉嫌 楊麗環 藍綠陣營 大聲公 文宣 勝利 作成 員會民 翻天 愕 吳育昇則 開會議 不甘示弱 鷹 喃喃 紀國棟 評 視 自備 受理 偷偷 起身 將舉 五月 疑民進 十七 場邊 他現 以麥克風 結聯盟籍 排議程 靜待 會上 分開始 門議 週排 週末 觀瞻 搶先 動向 火速 大致 並由 無心 團主張 重演 將不會 出任 作勢 一大早 士氣 一出 及民進 冗長 法官 排班 作風 兩場 迫不得已 因故 蠻幹 山雨 坐鎮 裁示 將請 院會議 侮辱 忠信 許智傑 依慣 人員應 便是 開會前 拉到 所稱 發言單 全是 銘 召開國 牌 參閱 問他 辦公聽會 歌聲 謝年 排案權 將再 辦完 進黨團 送給 大院 重兵 施行 不久 重來 兩週 出乎意料 天委員會 簽字 集思廣益 經委會 啟臣 由院 繞 簽的 回籠 交出 他將 一上午 不免 肆無忌憚 還將 單一 輪到 邁下 之時 忠 易位 步伐 挫傷 黨並 紙條 休兵 甲動 開公聽會 抽出 盧嘉辰 勝訴 嚴加 延期 播放 開成 揚揚 揚言服 脖子 無非 團絕 。中國 眼 耍 次會 此種 由國民黨籍 居 乖乖 陣 質疑民 先簽 搞花樣 意旨 閹割 執政時 侵占 濫用 明兩天 發洩 跌倒 丟給 邊 未接 週內 反將 慶忠下 以人數 占據會 原地 八名 。他 六天 並批 場地 開議場 已緊 不下 不慎 一案 男性 全員到 盯 則認 黨團應 歐珀 欲來 譏諷 票 叫陣 前晚 雖未 席召委 紅樓 離婚 將開黨 縱使 各排 草草 插隊 附和 過民進 防堵 搶下 行文 邁委員 歷次 諸公 考核 急動員令 這已經 幸好 支麥克風 撕 將進入 總務處 幾點 買單 下個 第一位 持久 暗諷 清泉 擔心民 動手 內閣制 全黨 地面 寄給 見招 中國國 週四 成會 憲政規定 矚目 醫務室 人手 引發民 不承 又將 並展 組團 餐敘 音響 批國民黨 沒法 緩辦 回擊 軍令狀 蔡錦隆 一審 清一色 占先 還宣稱 過服 剛才 有民進 一召委 急動員 依慣例 四成 還對 的則 洪水 姚文智 台聯將 王郁琦會 沒意 譴責國民黨 妄想 案審查 黨應 借用 剛 前夕 尹啟 抵 召委輪流 有效性 但會議 認會議 攻守 改由 防委員會 例應 餵 無賴 第九 無解 設下 唸完 該表決 院中 力阻 許國民黨 歧視 先將 互不 再行 聽聞 參事 談判桌 地將 節如 旋即 陳淑惠 所為 以黨 轉戰 達動員令 發說 團來 發言權 力保 管理法 貸 再排 避開 依國安 追加 請民進 劉建國 排在後面 免不了 好意 不太 團質疑 並爆發 三名 數及 一級 關門 鵬則 排開 顧好 一席 區內 偷跑 壓著 責無旁 錯愕 還把 服貿本 張慶忠將 領到 發言時 還以 還來 分組 也絕 以閃電 隨之 中民進 員會將 第六十一 音量 仍無法 茲 名冊 武器 亂成 並輪番 生民 肉搏 此協議 司馬昭之心 成一團 開打 延到 儀式 預先 林滄敏 夾帶 召委時 差點 拿起 召委則 確 遂 召委人選 與民進 大罵 猛烈 提散 團要 登載 唱名 ！立法院 認為現 倪安 開會時 一邊念 徐少萍 力主 若下 支隱 交通委 商議 。蘇貞昌 將發動 團持 倒地 原在 不懷 重排 真要 八壯丁 六個 福利部 將由 另行 無線 竟是 以爭 有別 三場 一整 無異議 恰當 綠營則 合情合理 有略 滿場 表情 投下 問民進 字幕 單方 譴責民 送出去 今起 娘子 台賓館 武行 前次 郝 字樣 委員將 覆 搬出 不會用 此話 桌 邁並 自省 手臂 則有 多處 成員士氣 堇 黨意 據悉 蘇貞昌還 開到 認帳 奉陪到底 隨後將 顯示民 硬碰硬 改採 推派 虛耗 壯漢 堅 林岱 空缺 口頭 召委排 新一 ...

# %%
for word, score in model.most_similar(positive=[u'fb']):
    print word, score
# Out:
# bit 0.9158603549
# 網址 0.902209997177
# www 0.902153849602
# goo 0.900790333748
# ly 0.898342311382
# cc 0.897235393524
# https 0.896780908108
# facebook 0.893847346306
# httPS 0.893139243126
# youtube 0.892292499542

# %%
for word, score in model.most_similar(positive=[u'ptt']):
    print word, score
# Out:
# cc 0.950878560543
# gl 0.943984031677
# facEBOOK 0.931619405746
# www 0.928510248661
# gov 0.925413191319
# org 0.923778295517
# events 0.922998607159
# tw 0.919508218765
# html 0.917458057404
# youtube 0.914049744606

# %%
for word, score in model.most_similar(positive=[u'鼎王']):
    print word, score
# Out:
# 陽明 0.783542275429
# 副手 0.775316238403
# 萬元台 0.773864090443
# 秀沛 0.759614288807
# 好康 0.757791340351
# 多單 0.757316470146
# 地價 0.75420576334
# 下單 0.74730604887
# 中鋼 0.7467867136
# 點閱 0.746247172356

# %%
for word, score in model.most_similar(positive=[u'遊戲業']):
    print word, score
# Out:
# 作者 0.616579771042
# 崛起 0.613565683365
# 看透 0.582710504532
# Socialize 0.581575393677
# 線上 0.575055241585
# 部承認 0.568206906319
# 喜劇 0.568120121956
# 交通安全 0.567019164562
# 偏安 0.566573679447
# 環保 0.564066290855

# %%
pca = pca(n_components=2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-60-fd2b333b6751> in <module>()
# ----> 1 pca = pca(n_components=2)
#
# NameError: name 'pca' is not defined

# %%
X = np.array(model.syn0norm)[index]
X_r = pca.fit(X).transform(X)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-58-08fe4934ca15> in <module>()
#       1 X = np.array(model.syn0norm)[index]
# ----> 2 X_r = pca.fit(X).transform(X)
#
# NameError: name 'pca' is not defined

# %%
X_r
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-57-5f7b689919db> in <module>()
# ----> 1 X_r
#
# NameError: name 'X_r' is not defined
